# %%
import pandas as pd

ratings = pd.read_csv('data/ratings.csv')
# Out:
#           Date                     Name  Year        Letterboxd URI  Rating
# 0   2025-12-01         Wicked: For Good  2025  https://boxd.it/AyfK     2.0
# 1   2025-12-01                Novocaine  2025  https://boxd.it/JmdA     2.5
# 2   2025-12-01                 Zootopia  2016  https://boxd.it/84xS     4.0
# 3   2025-12-01               Zootopia 2  2025  https://boxd.it/F0vO     4.0
# 4   2025-12-05                Road Trip  2000  https://boxd.it/1Z4a     3.5
# ..         ...                      ...   ...                   ...     ...
# 64  2026-05-06    The Devil Wears Prada  2006  https://boxd.it/2awE     3.0
# 65  2026-05-06  The Devil Wears Prada 2  2026  https://boxd.it/Oags     3.0
# 66  2026-05-10                 Serenity  2019  https://boxd.it/g9sk     2.0
# 67  2026-05-13            Mortal Kombat  2021  https://boxd.it/gswA     3.0
# 68  2026-05-14         Mortal Kombat II  2026  https://boxd.it/z6iO     3.0
#
# [69 rows x 5 columns]
